# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit, prange
import cv2
import os
import time

# ==========================================
# 1. CONFIGURATION
# ==========================================

# Resolution & Output
WIDTH = 1000
HEIGHT = 750
OUTPUT_DIR = "Kerr_frames_HR"
OUTPUT_VIDEO = "kerr_black_hole_HR_orbit.mp4"

# Physics Parameters
FOV = 40.0           # Slightly tighter FOV for the larger distance
SPIN_A = 0.99        # Near-extremal spin (0.99)
RS = 1.0
# Event Horizon radius for Kerr
R_HORIZON = RS + np.sqrt(RS**2 - SPIN_A**2)

# Integration Settings
STEP_SIZE = 0.05
MAX_STEPS = 3000     # Increased for high precision

# Animation Settings
NUM_FRAMES = 360
FPS = 30
CAM_DIST = 44.0      # Increased distance
ORBIT_INCLINATION = 30.0 # +/- 30 degrees dip

# Ensure output directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ==========================================
# 2. NUMBA-ACCELERATED PHYSICS KERNELS
# ==========================================

@njit
def get_inverse_metric(pos):
    """
    Returns the inverse metric components g^uv at position (r, theta).
    Boyer-Lindquist coordinates.
    """
    r = pos[1]
    theta = pos[2]

    sin_th = np.sin(theta)
    cos_th = np.cos(theta)
    sigma = r**2 + (SPIN_A * cos_th)**2
    delta = r**2 - 2.0 * RS * r + SPIN_A**2

    # Inverse Metric Components
    inv_g_tt = - ((r**2 + SPIN_A**2)**2 - delta * (SPIN_A * sin_th)**2) / (delta * sigma)
    inv_g_rr = delta / sigma
    inv_g_thth = 1.0 / sigma

    # Polar singularity safeguard
    sin_sq = sin_th**2
    if sin_sq < 1e-9: sin_sq = 1e-9

    inv_g_phiphi = (delta - SPIN_A**2 * sin_sq) / (delta * sigma * sin_sq)
    inv_g_tphi = - (2.0 * RS * r * SPIN_A) / (delta * sigma)

    return inv_g_tt, inv_g_rr, inv_g_thth, inv_g_phiphi, inv_g_tphi

@njit
def hamiltonian(pos, p):
    g_tt, g_rr, g_thth, g_ph, g_tph = get_inverse_metric(pos)
    H = 0.5 * (g_tt * p[0]**2 +
               g_rr * p[1]**2 +
               g_thth * p[2]**2 +
               g_ph * p[3]**2 +
               2.0 * g_tph * p[0] * p[3])
    return H

@njit
def get_derivatives(state):
    pos = state[:4]
    p = state[4:]
    g_tt, g_rr, g_thth, g_ph, g_tph = get_inverse_metric(pos)

    dt  = g_tt * p[0] + g_tph * p[3]
    dr  = g_rr * p[1]
    dth = g_thth * p[2]
    dph = g_ph * p[3] + g_tph * p[0]

    # Numerical differentiation for forces
    epsilon = 1e-5

    # dH/dr
    pos_plus = np.array([pos[0], pos[1] + epsilon, pos[2], pos[3]])
    pos_minus = np.array([pos[0], pos[1] - epsilon, pos[2], pos[3]])
    dH_dr = (hamiltonian(pos_plus, p) - hamiltonian(pos_minus, p)) / (2.0 * epsilon)

    # dH/dtheta
    pos_plus[1] = pos[1]
    pos_minus[1] = pos[1]
    pos_plus[2] = pos[2] + epsilon
    pos_minus[2] = pos[2] - epsilon
    dH_dth = (hamiltonian(pos_plus, p) - hamiltonian(pos_minus, p)) / (2.0 * epsilon)

    dpt = 0.0
    dpphi = 0.0
    dpr = -dH_dr
    dpth = -dH_dth

    return np.array([dt, dr, dth, dph, dpt, dpr, dpth, dpphi])

@njit
def rk4_step_kerr(state, h):
    k1 = get_derivatives(state)
    k2 = get_derivatives(state + 0.5 * h * k1)
    k3 = get_derivatives(state + 0.5 * h * k2)
    k4 = get_derivatives(state + h * k3)
    return state + (h / 6.0) * (k1 + 2*k2 + 2*k3 + k4)

@njit
def get_disk_color(r, x_hit, y_hit):
    """
    Procedural accretion disk texture.
    Using Cartesian (x,y) for pattern to avoid 'atan2' branch cut artifacts.
    """
    # Create pattern using Cartesian coords to ensure continuity
    # Spiral arms: sin(log(r)*A + angle)
    # Angle can be computed as arctan2, but we must be careful.
    # Instead, we use a noise function based on x,y which has no singularity.

    angle = np.arctan2(y_hit, x_hit)
    scale = 3.0

    # Spiral + Rings
    # Adding a small rotation to the spiral based on radius to simulate differential rotation
    spiral = np.sin(r * scale + angle * 2.0)
    rings = np.sin(r * 5.0)

    # Base brightness
    brightness = 0.5 + 0.25 * spiral + 0.25 * rings

    # Doppler Beaming (Relativistic boosting)
    # Approaching side (x < 0 usually) is brighter
    beaming = 1.0 - 0.5 * (x_hit / (r + 0.1))
    brightness *= beaming

    # Temperature Gradient (Hotter near center)
    norm_r = (r - R_HORIZON) / 15.0
    col_r = 1.0 * brightness
    col_g = (0.3 + 0.5 * norm_r) * brightness
    col_b = (0.1 + 0.8 * norm_r) * brightness

    return np.array([col_r, col_g, col_b])

@njit
def ray_march_kerr(cam_pos_bl, ray_p_bl):
    state = np.concatenate((cam_pos_bl, ray_p_bl))

    for i in range(MAX_STEPS):
        prev_r = state[1]
        prev_th = state[2]

        # --- Adaptive Step Size ---
        # 1. Slow down near Event Horizon
        if state[1] < 2.0 * RS:
            h_factor = 0.2
        # 2. Slow down near Polar Singularity to prevent artifacts
        elif np.abs(np.sin(state[2])) < 0.15:
            h_factor = 0.1
        else:
            h_factor = 1.0

        current_h = STEP_SIZE * h_factor

        state = rk4_step_kerr(state, current_h)

        r = state[1]
        th = state[2]

        # Horizon Check
        if r < R_HORIZON * 1.05:
            return np.array([0.0, 0.0, 0.0])

        # Escape Check
        if r > CAM_DIST * 1.5:
             # Starfield background (simple noise based on direction)
             # Use phi and theta to map stars
             phi = state[3]
             stars = np.sin(phi * 30.0) * np.sin(th * 30.0)
             if stars > 0.98: return np.array([1.0, 1.0, 1.0])
             return np.array([0.0, 0.0, 0.02])

        # Disk Intersection Check (Equatorial Plane theta = pi/2)
        # Check if we crossed pi/2
        if (prev_th - np.pi/2.0) * (th - np.pi/2.0) < 0.0:
            # Linear interpolation for exact hit radius
            frac = abs(prev_th - np.pi/2.0) / (abs(prev_th - np.pi/2.0) + abs(th - np.pi/2.0))
            hit_r = prev_r + (r - prev_r) * frac

            # Get exact phi for texture
            prev_phi = state[3] - (state[3] - state[7]*current_h) # Approx prev phi
            # Note: state[3] is current phi.
            # We need to be careful interpolating phi if it wrapped around 2pi.
            # However, for texture generation, we convert to Cartesian immediately.
            hit_phi = state[3] # Approximate is fine for texture noise

            if 2.5 * RS < hit_r < 18.0 * RS:
                # Convert to Cartesian on the disk plane for texture lookup
                x_h = hit_r * np.cos(hit_phi)
                y_h = hit_r * np.sin(hit_phi)
                return get_disk_color(hit_r, x_h, y_h)

    return np.array([0.0, 0.0, 0.0])

@njit(parallel=True)
def render_frame_data(width, height, cam_r, cam_theta, cam_phi, fov):
    image = np.zeros((height, width, 3))
    aspect = width / height

    # 1. Camera Position in Global Cartesian
    cx = cam_r * np.sin(cam_theta) * np.cos(cam_phi)
    cy = cam_r * np.sin(cam_theta) * np.sin(cam_phi)
    cz = cam_r * np.cos(cam_theta)
    cam_pos_cart = np.array([cx, cy, cz])

    # 2. Camera Basis Vectors
    # Look at origin
    fwd = -cam_pos_cart / np.linalg.norm(cam_pos_cart)

    # Robust Up vector
    # If looking straight down/up (Z-axis), change Up reference
    glob_up = np.array([0.0, 0.0, 1.0])
    if np.abs(np.dot(fwd, glob_up)) > 0.95:
        glob_up = np.array([0.0, 1.0, 0.0])

    right = np.cross(fwd, glob_up)
    right = right / np.linalg.norm(right)
    up = np.cross(right, fwd)

    # Screen dimensions
    fov_rad = np.radians(fov)
    half_h = np.tan(fov_rad/2.0)
    half_w = half_h * aspect

    for y in prange(height):
        for x in prange(width):
            sx = (x / width) * 2.0 - 1.0
            sy = 1.0 - (y / height) * 2.0

            # Ray Direction in Cartesian
            ray_dir_cart = fwd + right * (sx * half_w) + up * (sy * half_h)
            ray_dir_cart = ray_dir_cart / np.linalg.norm(ray_dir_cart)

            # Convert to Boyer-Lindquist Initial State
            init_pos = np.array([0.0, cam_r, cam_theta, cam_phi])

            # Convert Momentum (Cartesian -> Spherical)
            vx, vy, vz = ray_dir_cart[0], ray_dir_cart[1], ray_dir_cart[2]

            # Unit vectors for spherical coords at camera position
            # r_hat
            sin_th = np.sin(cam_theta)
            cos_th = np.cos(cam_theta)
            sin_ph = np.sin(cam_phi)
            cos_ph = np.cos(cam_phi)

            # Dot products to project Cartesian velocity v onto spherical basis
            v_dot_rhat = vx*sin_th*cos_ph + vy*sin_th*sin_ph + vz*cos_th
            v_dot_thhat = vx*cos_th*cos_ph + vy*cos_th*sin_ph - vz*sin_th
            v_dot_phhat = -vx*sin_ph + vy*cos_ph

            # Canonical Momenta
            # p_r = v_r
            # p_theta = r * v_theta
            # p_phi = r * sin(theta) * v_phi
            pr = v_dot_rhat
            pth = cam_r * v_dot_thhat
            pph = cam_r * sin_th * v_dot_phhat

            init_p = np.array([-1.0, pr, pth, pph])

            image[y, x] = ray_march_kerr(init_pos, init_p)

    return image

# ==========================================
# 3. ORBIT LOGIC & EXECUTION
# ==========================================

def get_orbit_position(frame_idx, total_frames, distance, inclination_deg):
    """
    Calculates Camera (r, theta, phi) for an INCLINED orbit.
    This varies theta and phi simultaneously.
    """
    # Orbital angle (0 to 2pi)
    alpha = (2.0 * np.pi * frame_idx) / total_frames

    # Inclination (tilt around Y-axis, for example)
    inc_rad = np.radians(inclination_deg)

    # Parametric circle in 3D, tilted
    # Start with circle in X-Z plane (equatorial if Z is up? No, Kerr Z is axis of rotation)
    # Standard Kerr: Z is rotation axis. Equatorial plane is X-Y.
    # We want a circle that goes above and below X-Y.

    # 1. Circle in X-Y plane
    # x = d * cos(alpha)
    # y = d * sin(alpha)
    # z = 0

    # 2. Tilt it. Let's rotate around the X-axis by inclination angle.
    # New Y' = y * cos(inc) - z * sin(inc)
    # New Z' = y * sin(inc) + z * cos(inc)

    # Wait, if we want to orbit the black hole, we basically want to traverse phi.
    # Standard orbit: theta = 90 (equator).
    # Inclined orbit: theta oscillates between 90-inc and 90+inc.

    # Let's define the position vector in Cartesian, then convert to Spherical.
    # Orbit in a plane tilted by 'inc' relative to the equator.
    x_orbit = distance * np.cos(alpha)
    y_orbit = distance * np.sin(alpha) * np.cos(inc_rad)
    z_orbit = distance * np.sin(alpha) * np.sin(inc_rad)

    # Convert to r, theta, phi
    r = np.sqrt(x_orbit**2 + y_orbit**2 + z_orbit**2)
    theta = np.arccos(z_orbit / r)
    phi = np.arctan2(y_orbit, x_orbit)

    return r, theta, phi

def main():
    print("Initializing High-Res Kerr Orbit Simulation...")
    print(f"Output Directory: {OUTPUT_DIR}")
    print(f"Distance: {CAM_DIST}")
    print(f"Inclination: {ORBIT_INCLINATION} deg")

    # JIT Compile (Warmup)
    print("Compiling JIT kernels (this takes a moment)...")
    _ = render_frame_data(10, 10, 20.0, 1.5, 0.0, 60.0)
    print("Compilation Complete.")

    print(f"Rendering {NUM_FRAMES} frames...")

    for i in range(NUM_FRAMES):
        filename = f"{OUTPUT_DIR}/frame_{i:03d}.png"

        if os.path.exists(filename):
            print(f"Frame {i} exists.")
            continue

        # Get Dynamic Camera Position
        cam_r, cam_theta, cam_phi = get_orbit_position(i, NUM_FRAMES, CAM_DIST, ORBIT_INCLINATION)

        t0 = time.time()
        img_data = render_frame_data(WIDTH, HEIGHT, cam_r, cam_theta, cam_phi, FOV)

        # Process Image
        img_data = np.clip(img_data, 0, 1) * 255.0
        img_bgr = img_data.astype(np.uint8)[..., ::-1] # RGB to BGR for OpenCV

        cv2.imwrite(filename, img_bgr)

        elapsed = time.time() - t0
        print(f"Frame {i+1}/{NUM_FRAMES} | Inc: {90 - np.degrees(cam_theta):.1f} deg | Time: {elapsed:.2f}s")

    # Compile Video
    print("Stitching video...")
    images = [img for img in sorted(os.listdir(OUTPUT_DIR)) if img.endswith(".png")]
    if not images: return

    frame_path = os.path.join(OUTPUT_DIR, images[0])
    frame = cv2.imread(frame_path)
    h, w, _ = frame.shape

    video = cv2.VideoWriter(OUTPUT_VIDEO, cv2.VideoWriter_fourcc(*'mp4v'), FPS, (w, h))

    for image in images:
        video.write(cv2.imread(os.path.join(OUTPUT_DIR, image)))

    video.release()
    print(f"Done! Video saved to {OUTPUT_VIDEO}")

if __name__ == "__main__":
    main()
# Out:
# Initializing High-Res Kerr Orbit Simulation...
# Output Directory: Kerr_frames_HR
# Distance: 44.0
# Inclination: 30.0 deg
# Compiling JIT kernels (this takes a moment)...
# Compilation Complete.
# Rendering 360 frames...
# Frame 1/360 | Inc: 0.0 deg | Time: 129.25s
# Frame 2/360 | Inc: 0.5 deg | Time: 129.73s
# Frame 3/360 | Inc: 1.0 deg | Time: 132.91s
# Frame 4/360 | Inc: 1.5 deg | Time: 129.15s
# Frame 5/360 | Inc: 2.0 deg | Time: 129.97s
# Frame 6/360 | Inc: 2.5 deg | Time: 128.63s
# Frame 7/360 | Inc: 3.0 deg | Time: 128.42s
# Frame 8/360 | Inc: 3.5 deg | Time: 128.70s
# Frame 9/360 | Inc: 4.0 deg | Time: 127.74s
# Frame 10/360 | Inc: 4.5 deg | Time: 127.52s
# Frame 11/360 | Inc: 5.0 deg | Time: 127.04s
# Frame 12/360 | Inc: 5.5 deg | Time: 127.36s
# Frame 13/360 | Inc: 6.0 deg | Time: 126.97s
# Frame 14/360 | Inc: 6.5 deg | Time: 133.92s
# Frame 15/360 | Inc: 6.9 deg | Time: 126.78s
# Frame 16/360 | Inc: 7.4 deg | Time: 125.86s
# Frame 17/360 | Inc: 7.9 deg | Time: 125.73s
# Frame 18/360 | Inc: 8.4 deg | Time: 125.74s
# Frame 19/360 | Inc: 8.9 deg | Time: 125.54s
# Frame 20/360 | Inc: 9.4 deg | Time: 125.04s
# Frame 21/360 | Inc: 9.8 deg | Time: 124.74s
# Frame 22/360 | Inc: 10.3 deg | Time: 127.62s
# Frame 23/360 | Inc: 10.8 deg | Time: 123.25s
# Frame 24/360 | Inc: 11.3 deg | Time: 122.98s
# Frame 25/360 | Inc: 11.7 deg | Time: 122.52s
# Frame 26/360 | Inc: 12.2 deg | Time: 123.29s
# Frame 27/360 | Inc: 12.7 deg | Time: 122.43s
# Frame 28/360 | Inc: 13.1 deg | Time: 121.61s
# Frame 29/360 | Inc: 13.6 deg | Time: 121.14s
# Frame 30/360 | Inc: 14.0 deg | Time: 121.07s
# Frame 31/360 | Inc: 14.5 deg | Time: 120.67s
# Frame 32/360 | Inc: 14.9 deg | Time: 120.38s
# Frame 33/360 | Inc: 15.4 deg | Time: 121.38s
# Frame 34/360 | Inc: 15.8 deg | Time: 122.65s
# Frame 35/360 | Inc: 16.2 deg | Time: 122.37s
# Frame 36/360 | Inc: 16.7 deg | Time: 118.23s
# Frame 37/360 | Inc: 17.1 deg | Time: 118.16s
# Frame 38/360 | Inc: 17.5 deg | Time: 117.81s
# Frame 39/360 | Inc: 17.9 deg | Time: 117.19s
# Frame 40/360 | Inc: 18.3 deg | Time: 117.14s
# Frame 41/360 | Inc: 18.7 deg | Time: 116.58s
# Frame 42/360 | Inc: 19.1 deg | Time: 116.41s
# Frame 43/360 | Inc: 19.5 deg | Time: 116.15s
# Frame 44/360 | Inc: 19.9 deg | Time: 115.63s
# Frame 45/360 | Inc: 20.3 deg | Time: 115.50s
# Frame 46/360 | Inc: 20.7 deg | Time: 117.81s
# Frame 47/360 | Inc: 21.1 deg | Time: 118.46s
# Frame 48/360 | Inc: 21.4 deg | Time: 118.40s
# Frame 49/360 | Inc: 21.8 deg | Time: 117.86s
# Frame 50/360 | Inc: 22.2 deg | Time: 117.37s
# Frame 51/360 | Inc: 22.5 deg | Time: 118.84s
# Frame 52/360 | Inc: 22.9 deg | Time: 116.40s
# Frame 53/360 | Inc: 23.2 deg | Time: 116.07s
# Frame 54/360 | Inc: 23.5 deg | Time: 116.63s
# Frame 55/360 | Inc: 23.9 deg | Time: 115.54s
# Frame 56/360 | Inc: 24.2 deg | Time: 114.88s
# Frame 57/360 | Inc: 24.5 deg | Time: 114.63s
# Frame 58/360 | Inc: 24.8 deg | Time: 114.78s
# Frame 59/360 | Inc: 25.1 deg | Time: 114.02s
# Frame 60/360 | Inc: 25.4 deg | Time: 113.71s
# Frame 61/360 | Inc: 25.7 deg | Time: 113.69s
# Frame 62/360 | Inc: 25.9 deg | Time: 111.63s
# Frame 63/360 | Inc: 26.2 deg | Time: 109.81s
# Frame 64/360 | Inc: 26.5 deg | Time: 109.64s
# Frame 65/360 | Inc: 26.7 deg | Time: 110.53s
# Frame 66/360 | Inc: 26.9 deg | Time: 109.51s
# Frame 67/360 | Inc: 27.2 deg | Time: 109.28s
# Frame 68/360 | Inc: 27.4 deg | Time: 109.47s
# Frame 69/360 | Inc: 27.6 deg | Time: 109.37s
# Frame 70/360 | Inc: 27.8 deg | Time: 109.01s
# Frame 71/360 | Inc: 28.0 deg | Time: 109.49s
# Frame 72/360 | Inc: 28.2 deg | Time: 108.67s
# Frame 73/360 | Inc: 28.4 deg | Time: 109.72s
# Frame 74/360 | Inc: 28.6 deg | Time: 111.06s
# Frame 75/360 | Inc: 28.7 deg | Time: 110.10s
# Frame 76/360 | Inc: 28.9 deg | Time: 110.05s
# Frame 77/360 | Inc: 29.0 deg | Time: 109.65s
# Frame 78/360 | Inc: 29.2 deg | Time: 109.46s
# Frame 79/360 | Inc: 29.3 deg | Time: 109.47s
# Frame 80/360 | Inc: 29.4 deg | Time: 109.46s
# Frame 81/360 | Inc: 29.5 deg | Time: 108.88s
# Frame 82/360 | Inc: 29.6 deg | Time: 108.50s
# Frame 83/360 | Inc: 29.7 deg | Time: 108.30s
# Frame 84/360 | Inc: 29.8 deg | Time: 110.72s
# Frame 85/360 | Inc: 29.8 deg | Time: 108.47s
# Frame 86/360 | Inc: 29.9 deg | Time: 108.27s
# Frame 87/360 | Inc: 29.9 deg | Time: 109.16s
# Frame 88/360 | Inc: 30.0 deg | Time: 107.96s
# Frame 89/360 | Inc: 30.0 deg | Time: 108.14s
# Frame 90/360 | Inc: 30.0 deg | Time: 108.06s
# Frame 91/360 | Inc: 30.0 deg | Time: 107.91s
# Frame 92/360 | Inc: 30.0 deg | Time: 108.04s
# Frame 93/360 | Inc: 30.0 deg | Time: 107.92s
# Frame 94/360 | Inc: 30.0 deg | Time: 108.50s
# Frame 95/360 | Inc: 29.9 deg | Time: 104.96s
# Frame 96/360 | Inc: 29.9 deg | Time: 105.00s
# Frame 97/360 | Inc: 29.8 deg | Time: 105.08s
# Frame 98/360 | Inc: 29.8 deg | Time: 105.66s
# Frame 99/360 | Inc: 29.7 deg | Time: 105.32s
# Frame 100/360 | Inc: 29.6 deg | Time: 105.59s
# Frame 101/360 | Inc: 29.5 deg | Time: 105.88s
# Frame 102/360 | Inc: 29.4 deg | Time: 106.23s
# Frame 103/360 | Inc: 29.3 deg | Time: 106.22s
# Frame 104/360 | Inc: 29.2 deg | Time: 106.64s
# Frame 105/360 | Inc: 29.0 deg | Time: 106.92s
# Frame 106/360 | Inc: 28.9 deg | Time: 107.77s
# Frame 107/360 | Inc: 28.7 deg | Time: 110.85s
# Frame 108/360 | Inc: 28.6 deg | Time: 110.66s
# Frame 109/360 | Inc: 28.4 deg | Time: 111.15s
# Frame 110/360 | Inc: 28.2 deg | Time: 111.25s
# Frame 111/360 | Inc: 28.0 deg | Time: 111.44s
# Frame 112/360 | Inc: 27.8 deg | Time: 111.80s
# Frame 113/360 | Inc: 27.6 deg | Time: 111.88s
# Frame 114/360 | Inc: 27.4 deg | Time: 111.89s
# Frame 115/360 | Inc: 27.2 deg | Time: 112.79s
# Frame 116/360 | Inc: 26.9 deg | Time: 112.45s
# Frame 117/360 | Inc: 26.7 deg | Time: 113.85s
# Frame 118/360 | Inc: 26.5 deg | Time: 113.12s
# Frame 119/360 | Inc: 26.2 deg | Time: 113.32s
# Frame 120/360 | Inc: 25.9 deg | Time: 113.54s
# Frame 121/360 | Inc: 25.7 deg | Time: 113.73s
# Frame 122/360 | Inc: 25.4 deg | Time: 113.94s
# Frame 123/360 | Inc: 25.1 deg | Time: 114.07s
# Frame 124/360 | Inc: 24.8 deg | Time: 118.87s
# Frame 125/360 | Inc: 24.5 deg | Time: 118.87s
# Frame 126/360 | Inc: 24.2 deg | Time: 115.13s
# Frame 127/360 | Inc: 23.9 deg | Time: 115.53s
# Frame 128/360 | Inc: 23.5 deg | Time: 116.15s
# Frame 129/360 | Inc: 23.2 deg | Time: 116.62s
# Frame 130/360 | Inc: 22.9 deg | Time: 117.01s
# Frame 131/360 | Inc: 22.5 deg | Time: 117.14s
# Frame 132/360 | Inc: 22.2 deg | Time: 117.57s
# Frame 133/360 | Inc: 21.8 deg | Time: 117.87s
# Frame 134/360 | Inc: 21.4 deg | Time: 118.36s
# Frame 135/360 | Inc: 21.1 deg | Time: 118.40s
# Frame 136/360 | Inc: 20.7 deg | Time: 118.22s
# Frame 137/360 | Inc: 20.3 deg | Time: 119.01s
# Frame 138/360 | Inc: 19.9 deg | Time: 119.08s
# Frame 139/360 | Inc: 19.5 deg | Time: 119.34s
# Frame 140/360 | Inc: 19.1 deg | Time: 119.81s
# Frame 141/360 | Inc: 18.7 deg | Time: 120.21s
# Frame 142/360 | Inc: 18.3 deg | Time: 120.68s
# Frame 143/360 | Inc: 17.9 deg | Time: 120.98s
# Frame 144/360 | Inc: 17.5 deg | Time: 121.05s
# Frame 145/360 | Inc: 17.1 deg | Time: 121.92s
# Frame 146/360 | Inc: 16.7 deg | Time: 122.11s
# Frame 147/360 | Inc: 16.2 deg | Time: 123.97s
# Frame 148/360 | Inc: 15.8 deg | Time: 122.71s
# Frame 149/360 | Inc: 15.4 deg | Time: 120.08s
# Frame 150/360 | Inc: 14.9 deg | Time: 120.18s
# Frame 151/360 | Inc: 14.5 deg | Time: 120.70s
# Frame 152/360 | Inc: 14.0 deg | Time: 121.22s
# Frame 153/360 | Inc: 13.6 deg | Time: 121.92s
# Frame 154/360 | Inc: 13.1 deg | Time: 121.97s
# Frame 155/360 | Inc: 12.7 deg | Time: 124.29s
# Frame 156/360 | Inc: 12.2 deg | Time: 123.66s
# Frame 157/360 | Inc: 11.7 deg | Time: 123.48s
# Frame 158/360 | Inc: 11.3 deg | Time: 126.09s
# Frame 159/360 | Inc: 10.8 deg | Time: 127.42s
# Frame 160/360 | Inc: 10.3 deg | Time: 128.03s
# Frame 161/360 | Inc: 9.8 deg | Time: 128.43s
# Frame 162/360 | Inc: 9.4 deg | Time: 128.42s
# Frame 163/360 | Inc: 8.9 deg | Time: 129.20s
# Frame 164/360 | Inc: 8.4 deg | Time: 128.94s
# Frame 165/360 | Inc: 7.9 deg | Time: 129.63s
# Frame 166/360 | Inc: 7.4 deg | Time: 130.14s
# Frame 167/360 | Inc: 6.9 deg | Time: 129.90s
# Frame 168/360 | Inc: 6.5 deg | Time: 126.57s
# Frame 169/360 | Inc: 6.0 deg | Time: 126.73s
# Frame 170/360 | Inc: 5.5 deg | Time: 127.45s
# Frame 171/360 | Inc: 5.0 deg | Time: 127.24s
# Frame 172/360 | Inc: 4.5 deg | Time: 127.64s
# Frame 173/360 | Inc: 4.0 deg | Time: 128.28s
# Frame 174/360 | Inc: 3.5 deg | Time: 128.21s
# Frame 175/360 | Inc: 3.0 deg | Time: 128.78s
# Frame 176/360 | Inc: 2.5 deg | Time: 129.27s
# Frame 177/360 | Inc: 2.0 deg | Time: 128.96s
# Frame 178/360 | Inc: 1.5 deg | Time: 129.41s
# Frame 179/360 | Inc: 1.0 deg | Time: 129.65s
# Frame 180/360 | Inc: 0.5 deg | Time: 130.49s
# Frame 181/360 | Inc: 0.0 deg | Time: 131.40s
# Frame 182/360 | Inc: -0.5 deg | Time: 130.08s
# Frame 183/360 | Inc: -1.0 deg | Time: 129.69s
# Frame 184/360 | Inc: -1.5 deg | Time: 129.10s
# Frame 185/360 | Inc: -2.0 deg | Time: 130.62s
# Frame 186/360 | Inc: -2.5 deg | Time: 132.66s
# Frame 187/360 | Inc: -3.0 deg | Time: 133.19s
# Frame 188/360 | Inc: -3.5 deg | Time: 132.57s
# Frame 189/360 | Inc: -4.0 deg | Time: 131.77s
# Frame 190/360 | Inc: -4.5 deg | Time: 131.60s
# Frame 191/360 | Inc: -5.0 deg | Time: 132.06s
# Frame 192/360 | Inc: -5.5 deg | Time: 130.59s
# Frame 193/360 | Inc: -6.0 deg | Time: 130.37s
# Frame 194/360 | Inc: -6.5 deg | Time: 130.07s
# Frame 195/360 | Inc: -6.9 deg | Time: 129.70s
# Frame 196/360 | Inc: -7.4 deg | Time: 129.38s
# Frame 197/360 | Inc: -7.9 deg | Time: 129.06s
# Frame 198/360 | Inc: -8.4 deg | Time: 129.21s
# Frame 199/360 | Inc: -8.9 deg | Time: 128.63s
# Frame 200/360 | Inc: -9.4 deg | Time: 128.25s
# Frame 201/360 | Inc: -9.8 deg | Time: 127.90s
# Frame 202/360 | Inc: -10.3 deg | Time: 127.61s
# Frame 203/360 | Inc: -10.8 deg | Time: 129.94s
# Frame 204/360 | Inc: -11.3 deg | Time: 127.48s
# Frame 205/360 | Inc: -11.7 deg | Time: 127.21s
# Frame 206/360 | Inc: -12.2 deg | Time: 126.20s
# Frame 207/360 | Inc: -12.7 deg | Time: 125.91s
# Frame 208/360 | Inc: -13.1 deg | Time: 125.71s
# Frame 209/360 | Inc: -13.6 deg | Time: 125.60s
# Frame 210/360 | Inc: -14.0 deg | Time: 125.16s
# Frame 211/360 | Inc: -14.5 deg | Time: 124.74s
# Frame 212/360 | Inc: -14.9 deg | Time: 124.79s
# Frame 213/360 | Inc: -15.4 deg | Time: 124.16s
# Frame 214/360 | Inc: -15.8 deg | Time: 123.22s
# Frame 215/360 | Inc: -16.2 deg | Time: 122.76s
# Frame 216/360 | Inc: -16.7 deg | Time: 122.31s
# Frame 217/360 | Inc: -17.1 deg | Time: 122.11s
# Frame 218/360 | Inc: -17.5 deg | Time: 120.94s
# Frame 219/360 | Inc: -17.9 deg | Time: 117.78s
# Frame 220/360 | Inc: -18.3 deg | Time: 117.58s
# Frame 221/360 | Inc: -18.7 deg | Time: 117.96s
# Frame 222/360 | Inc: -19.1 deg | Time: 117.31s
# Frame 223/360 | Inc: -19.5 deg | Time: 116.75s
# Frame 224/360 | Inc: -19.9 deg | Time: 116.33s
# Frame 225/360 | Inc: -20.3 deg | Time: 116.09s
# Frame 226/360 | Inc: -20.7 deg | Time: 116.16s
# Frame 227/360 | Inc: -21.1 deg | Time: 115.95s
# Frame 228/360 | Inc: -21.4 deg | Time: 115.60s
# Frame 229/360 | Inc: -21.8 deg | Time: 115.47s
# Frame 230/360 | Inc: -22.2 deg | Time: 115.09s
# Frame 231/360 | Inc: -22.5 deg | Time: 115.38s
# Frame 232/360 | Inc: -22.9 deg | Time: 114.43s
# Frame 233/360 | Inc: -23.2 deg | Time: 115.52s
# Frame 234/360 | Inc: -23.5 deg | Time: 113.60s
# Frame 235/360 | Inc: -23.9 deg | Time: 113.24s
# Frame 236/360 | Inc: -24.2 deg | Time: 113.05s
# Frame 237/360 | Inc: -24.5 deg | Time: 112.80s
# Frame 238/360 | Inc: -24.8 deg | Time: 112.33s
# Frame 239/360 | Inc: -25.1 deg | Time: 112.20s
# Frame 240/360 | Inc: -25.4 deg | Time: 111.85s
# Frame 241/360 | Inc: -25.7 deg | Time: 111.47s
# Frame 242/360 | Inc: -25.9 deg | Time: 110.95s
# Frame 243/360 | Inc: -26.2 deg | Time: 110.72s
# Frame 244/360 | Inc: -26.5 deg | Time: 110.95s
# Frame 245/360 | Inc: -26.7 deg | Time: 110.82s
# Frame 246/360 | Inc: -26.9 deg | Time: 110.37s
# Frame 247/360 | Inc: -27.2 deg | Time: 110.23s
# Frame 248/360 | Inc: -27.4 deg | Time: 110.63s
# Frame 249/360 | Inc: -27.6 deg | Time: 110.12s
# Frame 250/360 | Inc: -27.8 deg | Time: 109.98s
# Frame 251/360 | Inc: -28.0 deg | Time: 109.88s
# Frame 252/360 | Inc: -28.2 deg | Time: 109.51s
# Frame 253/360 | Inc: -28.4 deg | Time: 109.73s
# Frame 254/360 | Inc: -28.6 deg | Time: 109.37s
# Frame 255/360 | Inc: -28.7 deg | Time: 109.30s
# Frame 256/360 | Inc: -28.9 deg | Time: 109.28s
# Frame 257/360 | Inc: -29.0 deg | Time: 108.97s
# Frame 258/360 | Inc: -29.2 deg | Time: 109.02s
# Frame 259/360 | Inc: -29.3 deg | Time: 109.08s
# Frame 260/360 | Inc: -29.4 deg | Time: 108.96s
# Frame 261/360 | Inc: -29.5 deg | Time: 108.80s
# Frame 262/360 | Inc: -29.6 deg | Time: 108.67s
# Frame 263/360 | Inc: -29.7 deg | Time: 109.00s
# Frame 264/360 | Inc: -29.8 deg | Time: 109.28s
# Frame 265/360 | Inc: -29.8 deg | Time: 108.72s
# Frame 266/360 | Inc: -29.9 deg | Time: 110.34s
# Frame 267/360 | Inc: -29.9 deg | Time: 108.85s
# Frame 268/360 | Inc: -30.0 deg | Time: 108.60s
# Frame 269/360 | Inc: -30.0 deg | Time: 108.55s
# Frame 270/360 | Inc: -30.0 deg | Time: 108.59s
# Frame 271/360 | Inc: -30.0 deg | Time: 108.51s
# Frame 272/360 | Inc: -30.0 deg | Time: 109.12s
# Frame 273/360 | Inc: -30.0 deg | Time: 108.67s
# Frame 274/360 | Inc: -30.0 deg | Time: 108.90s
# Frame 275/360 | Inc: -29.9 deg | Time: 108.79s
# Frame 276/360 | Inc: -29.9 deg | Time: 108.66s
# Frame 277/360 | Inc: -29.8 deg | Time: 108.45s
# Frame 278/360 | Inc: -29.8 deg | Time: 108.68s
# Frame 279/360 | Inc: -29.7 deg | Time: 108.98s
# Frame 280/360 | Inc: -29.6 deg | Time: 109.19s
# Frame 281/360 | Inc: -29.5 deg | Time: 108.86s
# Frame 282/360 | Inc: -29.4 deg | Time: 108.92s
# Frame 283/360 | Inc: -29.3 deg | Time: 109.04s
# Frame 284/360 | Inc: -29.2 deg | Time: 109.28s
# Frame 285/360 | Inc: -29.0 deg | Time: 109.27s
# Frame 286/360 | Inc: -28.9 deg | Time: 109.24s
# Frame 287/360 | Inc: -28.7 deg | Time: 109.28s
# Frame 288/360 | Inc: -28.6 deg | Time: 109.08s
# Frame 289/360 | Inc: -28.4 deg | Time: 109.36s
# Frame 290/360 | Inc: -28.2 deg | Time: 109.67s
# Frame 291/360 | Inc: -28.0 deg | Time: 109.79s
# Frame 292/360 | Inc: -27.8 deg | Time: 109.55s
# Frame 293/360 | Inc: -27.6 deg | Time: 109.93s
# Frame 294/360 | Inc: -27.4 deg | Time: 110.13s
# Frame 295/360 | Inc: -27.2 deg | Time: 110.37s
# Frame 296/360 | Inc: -26.9 deg | Time: 110.63s
# Frame 297/360 | Inc: -26.7 deg | Time: 110.98s
# Frame 298/360 | Inc: -26.5 deg | Time: 110.73s
# Frame 299/360 | Inc: -26.2 deg | Time: 113.07s
# Frame 300/360 | Inc: -25.9 deg | Time: 111.56s
# Frame 301/360 | Inc: -25.7 deg | Time: 111.24s
# Frame 302/360 | Inc: -25.4 deg | Time: 111.91s
# Frame 303/360 | Inc: -25.1 deg | Time: 112.10s
# Frame 304/360 | Inc: -24.8 deg | Time: 112.32s
# Frame 305/360 | Inc: -24.5 deg | Time: 113.02s
# Frame 306/360 | Inc: -24.2 deg | Time: 113.20s
# Frame 307/360 | Inc: -23.9 deg | Time: 113.28s
# Frame 308/360 | Inc: -23.5 deg | Time: 113.62s
# Frame 309/360 | Inc: -23.2 deg | Time: 114.30s
# Frame 310/360 | Inc: -22.9 deg | Time: 114.63s
# Frame 311/360 | Inc: -22.5 deg | Time: 114.86s
# Frame 312/360 | Inc: -22.2 deg | Time: 115.30s
# Frame 313/360 | Inc: -21.8 deg | Time: 116.02s
# Frame 314/360 | Inc: -21.4 deg | Time: 116.19s
# Frame 315/360 | Inc: -21.1 deg | Time: 116.32s
# Frame 316/360 | Inc: -20.7 deg | Time: 116.60s
# Frame 317/360 | Inc: -20.3 deg | Time: 116.93s
# Frame 318/360 | Inc: -19.9 deg | Time: 117.46s
# Frame 319/360 | Inc: -19.5 deg | Time: 117.14s
# Frame 320/360 | Inc: -19.1 deg | Time: 118.04s
# Frame 321/360 | Inc: -18.7 deg | Time: 118.12s
# Frame 322/360 | Inc: -18.3 deg | Time: 118.68s
# Frame 323/360 | Inc: -17.9 deg | Time: 119.32s
# Frame 324/360 | Inc: -17.5 deg | Time: 119.08s
# Frame 325/360 | Inc: -17.1 deg | Time: 119.67s
# Frame 326/360 | Inc: -16.7 deg | Time: 120.17s
# Frame 327/360 | Inc: -16.2 deg | Time: 120.69s
# Frame 328/360 | Inc: -15.8 deg | Time: 121.13s
# Frame 329/360 | Inc: -15.4 deg | Time: 121.47s
# Frame 330/360 | Inc: -14.9 deg | Time: 122.30s
# Frame 331/360 | Inc: -14.5 deg | Time: 121.72s
# Frame 332/360 | Inc: -14.0 deg | Time: 122.13s
# Frame 333/360 | Inc: -13.6 deg | Time: 122.68s
# Frame 334/360 | Inc: -13.1 deg | Time: 122.75s
# Frame 335/360 | Inc: -12.7 deg | Time: 122.98s
# Frame 336/360 | Inc: -12.2 deg | Time: 123.22s
# Frame 337/360 | Inc: -11.7 deg | Time: 123.82s
# Frame 338/360 | Inc: -11.3 deg | Time: 123.75s
# Frame 339/360 | Inc: -10.8 deg | Time: 124.23s
# Frame 340/360 | Inc: -10.3 deg | Time: 124.76s
# Frame 341/360 | Inc: -9.8 deg | Time: 124.34s
# Frame 342/360 | Inc: -9.4 deg | Time: 125.03s
# Frame 343/360 | Inc: -8.9 deg | Time: 125.70s
# Frame 344/360 | Inc: -8.4 deg | Time: 125.40s
# Frame 345/360 | Inc: -7.9 deg | Time: 126.17s
# Frame 346/360 | Inc: -7.4 deg | Time: 127.25s
# Frame 347/360 | Inc: -6.9 deg | Time: 126.42s
# Frame 348/360 | Inc: -6.5 deg | Time: 126.70s
# Frame 349/360 | Inc: -6.0 deg | Time: 126.90s
# Frame 350/360 | Inc: -5.5 deg | Time: 127.39s
# Frame 351/360 | Inc: -5.0 deg | Time: 127.54s
# Frame 352/360 | Inc: -4.5 deg | Time: 127.92s
# Frame 353/360 | Inc: -4.0 deg | Time: 128.49s
# Frame 354/360 | Inc: -3.5 deg | Time: 128.20s
# Frame 355/360 | Inc: -3.0 deg | Time: 128.63s
# Frame 356/360 | Inc: -2.5 deg | Time: 128.93s
# Frame 357/360 | Inc: -2.0 deg | Time: 129.71s
# Frame 358/360 | Inc: -1.5 deg | Time: 129.40s
# Frame 359/360 | Inc: -1.0 deg | Time: 130.11s
# Frame 360/360 | Inc: -0.5 deg | Time: 130.59s
# Stitching video...
# Done! Video saved to kerr_black_hole_HR_orbit.mp4
